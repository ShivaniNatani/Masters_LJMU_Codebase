# %% [markdown]
# # Multi-Modal Medical Report Generation: Exploratory Data Analysis
# **MSc Dissertation Research Pipeline - Phase 1**
#
# This notebook performs exploratory analysis on chest radiology datasets (MIMIC-CXR-JPG & IU Chest X-Ray).
# Key metrics computed:
# 1. Dataset summary statistics (Patients, Studies, Images ratio)
# 2. Clinical pathology / disease frequency distribution
# 3. Image resolution distribution (Width x Height)
# 4. Radiology report length distribution (Word count & tokens)
# 5. Vocabulary frequency distribution & top corpus words

# %%
import os
import sys
sys.path.insert(0, '..')

from scripts.run_eda import run_exploratory_data_analysis
from utils.env_check import verify_environment

# Verify environment and hardware
verify_environment()

# Execute EDA pipeline and render plots
run_exploratory_data_analysis(csv_path='../data/mock/mimic_cxr_mock.csv', figures_dir='../figures', results_dir='../results')
